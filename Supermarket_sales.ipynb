# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\hp\Downloads\Supemarket_sales\supermarket_sales - Sheet1.csv', parse_dates=['Date'])
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
#Display top 5 rows

# %%
df.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
#display last 5 rows of dataset

# %%
df.tail(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      C  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      B   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      A     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      A     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time  Payment  \
# 995       40.35         1   2.0175    42.3675 2019-01-29  13:46  Ewallet
# 996       97.38        10  48.6900  1022.4900 2019-03-02  17:16  Ewallet
# 997       31.84         1   1.5920    33.4320 2019-02-09  13:22     Cash
# 998       65.82         1   3.2910    69.1110 2019-02-22  15:33     Cash
# 999       88.34         7  30.9190   649.2990 2019-02-18  13:28     Cash
#
# ...

# %% [markdown]
# ###  About the column

# %%
# Invoice id: Computer generated sales slip invoice identification number

# Branch: Branch of supercenter
# (3 branches are available identified by A,B and C).

# City: location of supercenters

# Customer type: Type of customers, recorded
# by Members for customers using member card
# and Normal for without member card

# Gender: Gender type of customer

# Product line: General item ctegorization ggroups
# -Electronic accessories, Fashion accessories,
# Food and beverages, Health and beauty, Home
# and lifestyle, Sports and travel 

# Unit price: Price of each product in $

# Quantity : Number of products purchased by customer

# Tax: 5% tax fee for customer buying 

# Date: Date of purchase(Record avaliable from january2019 to december2019)

# Time: Purchase time (10am to 9am)

# Payement: Payement used by customer for purchase
# (3 method are available - Cash, Credit card and Ewalet)

# COGS: Cost of goods sold

#Gross margin percentage: Gross margin percentage

# Gross income : Gross income

#rating: Customer stratification rating on their
#overall shopping experience(On a scale of 1 to 10)

# %%
#display 5 random rows of dataset
df.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 223  279-62-1445      C  Naypyitaw        Member  Female
# 498  401-18-8016      B   Mandalay        Member  Female
# 982  139-32-4183      A     Yangon        Member  Female
# 857  748-45-2862      A     Yangon        Member  Female
# 828  538-22-0304      C  Naypyitaw        Normal    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 223     Fashion accessories       12.54         1   0.6270   13.1670
# 498       Sports and travel       98.13         1   4.9065  103.0365
# 982       Sports and travel       97.48         9  43.8660  921.1860
# 857      Home and lifestyle       28.31         4   5.6620  118.9020
# 828  Electronic accessories       64.95        10  32.4750  681.9750
#
#           Date   Time  Payment    cogs  gross margin percentage  gross income  \
# 223 2019-02-21  12:38     Cash   12.54                 4.761905        0.6270
# ...

# %%
# find shape of data
df.shape
# Out:
# (1000, 17)

# %%
#check null values
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
#getting information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
# get overall statistics
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
cat=[]
num=[]
for column in df.columns:
    if df[column].nunique() > 10:
        num.append(column)
    else:
        cat.append(column)

# %%
cat
# Out:
# ['Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Quantity',
#  'Payment',
#  'gross margin percentage']

# %% [markdown]
# ### Univariate Analysis

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
#Find Aggregate Sales among braches.(categorical column)
#one column at a time without considering relationship with other col
df['Branch'].value_counts().plot(kind='pie',autopct="%1.2f%%")
# Out:
# <AxesSubplot: ylabel='Branch'>

# %%
df['Branch'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
# find the most popular method used by customers
df['Payment'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
#find the distribn of customer ratings
sns.distplot(df['Rating'])
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Density'>

# %%
df['Rating'].skew()
# Out:
# 0.00900964876573073

# %%
#find the distribution of cost of goods sold
sns.distplot(df['cogs'])
# Out:
# <AxesSubplot: xlabel='cogs', ylabel='Density'>

# %%
df['cogs'].skew() # value +ve so postive skewness
# Out:
# 0.8925698049581418

# %%
sns.boxplot(df['cogs'])
# Out:
# <AxesSubplot: >

# %%
#q1,q2,q3.min,max
#some outliers are morethan max value

# %% [markdown]
# ###  Bivariate Analysis

# %%
#two variables at a time and perform analysis and determine there relationship

# %%
# does the cost of goods sold affect the ratings that the customers provide

# %%
num
# Out:
# ['Invoice ID',
#  'Unit price',
#  'Tax 5%',
#  'Total',
#  'Date',
#  'Time',
#  'cogs',
#  'gross income',
#  'Rating']

# %%
plt.scatter(df['cogs'],df['Rating'])
# no relationship

# %%
# does the cost of gross income affect the ratings that the customers provide

# %%
plt.scatter(df['gross income'],df['Rating'])
# no relationship

# %%
# find the most profitable branch as per gross income

# %%
sns.barplot(x='Branch',y='gross income', ci=None, data=df)
# Out:
# <AxesSubplot: xlabel='Branch', ylabel='gross income'>

# %%
# Is therre any relationship blw gender and grossincome
sns.barplot(x='Gender',y='gross income', ci=None, data=df)
# Out:
# <AxesSubplot: xlabel='Gender', ylabel='gross income'>

# %%
# find the product line that generates the most income
sns.barplot(x='Product line',y='gross income', ci=None, data=df)
plt.xticks(rotation=80)
plt.show()

# %%
#find the highest unit price in the product line
sns.barplot(x='Product line',y='Unit price', ci=None, data=df)
plt.xticks(rotation=80)
plt.show()

# %%
# find differnet payment methods used by customer citywise
pd.crosstab(df['City'],df['Payment'])
# Out:
# Payment    Cash  Credit card  Ewallet
# City
# Mandalay    110          109      113
# Naypyitaw   124           98      106
# Yangon      110          104      126

# %%
sns.heatmap(pd.crosstab(df['City'],df['Payment']))
# Out:
# <AxesSubplot: xlabel='Payment', ylabel='City'>

# %%
# which product line is purchased in the highest quantity
(df.groupby('Product line').sum()['Quantity']).plot(kind='bar')
# Out:
# <AxesSubplot: xlabel='Product line'>

# %%
#display daily sales by day of week
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
dw_mapping={0:'Mon',
            1:'tues',
            2:'wed'
           }

# %%
df['Date'].dt.dayofweek
# Out:
# 0      5
# 1      4
# 2      6
# 3      6
# 4      4
#       ..
# 995    1
# 996    5
# 997    5
# 998    4
# 999    0
# Name: Date, Length: 1000, dtype: int64
